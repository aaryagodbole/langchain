# %% [markdown]
# ## DuckDuckGo Search

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke('top news in india today')

print(results)
# Out:
# Read full articles, watch videos, browse thousands of titles and more on the " India " topic with Google News. 1 day ago · Today ' s top India news headlines, news on Indian politics, elections, government, business, technology, and Bollywood. News Headlines Today : Hindustan Times offers the most reliable news in politics, sports, entertainment and business, featuring National and International news Breaking News on Hindustan Times 5 days ago · India 's banking sector remained resilient, marked by strong balance sheet growth while bad loans have declined to a multi-decade low, a central bank report showed on Monday. Foreign companies... Dec 19, 2025 · Get the latest breaking news from India covering politics, economy, social issues, technology, sports, and more. Stay updated with in-depth analysis and top headlines from across the country.

# %%
print(search_tool.name)
print(search_tool.description)
print(search_tool.args)
# Out:
# duckduckgo_search
# A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
# {'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}

# %% [markdown]
# ## Shell Tool

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

results = shell_tool.invoke('whoami')

print(results)
# Out:
# Executing command:
#  whoami
# aaryagodbole
